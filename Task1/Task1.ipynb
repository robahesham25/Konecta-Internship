# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exploration

# %%
df = pd.read_csv("C:/Users/robah/OneDrive/Desktop/Konecta/Session1/dirty_cafe_sales.csv")

# %%
df
#jupyter shortcut; it outputs data in an organized table format and rows will be truncated if too long
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [10000 rows x 8 columns]

# %%
print(df)
#will output data as a string with no table-like format and rows will be truncated if too long
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [10000 rows x 8 columns]

# %%
#print(df.to_string()) 
#table-like format and it output all rows

# %%
#Notes about dataset
#All columns have either NAN,UNKOWN or ERROR except for the transaction ID

# %%
#first 5 rows if no parameter given else prints frist x rows where x is the head fucntion parameter
df.head(30)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0       ERROR
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211   UNKNOWN        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867       NaN        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 14    TXN_8915701     ERROR        2            1.5         3.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
# 20    TXN_3522028  Smoothie    ERROR            4.0        20.0
# 21    TXN_3567645  Smoothie        4            4.0        16.0
# 22    TXN_5132361  Sandwich        3            4.0        12.0
# 23    TXN_2616390  Sandwich        2            4.0         8.0
# 24    TXN_9400181  Sandwich        5            4.0        20.0
# 25    TXN_7958992  Smoothie        3            4.0         NaN
# 26    TXN_5183041    Cookie        5            1.0         5.0
# 27    TXN_5695074     Juice        4            3.0        12.0
# 28    TXN_8467949  Smoothie        5            4.0        20.0
# 29    TXN_7640952      Cake        4            3.0        12.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card       NaN       2023-03-31
# 6            ERROR  Takeaway       2023-10-06
# 7             Cash   UNKNOWN       2023-10-28
# 8              NaN  Takeaway       2023-07-28
# 9              NaN  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway            ERROR
# 12            Cash  In-store       2023-05-03
# 13             NaN  Takeaway       2023-06-01
# 14             NaN  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16             NaN       NaN       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash     ERROR       2023-03-25
# 19            Cash  Takeaway       2023-01-15
# 20            Cash  In-store       2023-04-04
# 21     Credit Card  Takeaway       2023-03-30
# 22  Digital Wallet  Takeaway       2023-12-01
# 23             NaN       NaN       2023-09-18
# 24            Cash  In-store       2023-06-03
# 25         UNKNOWN   UNKNOWN       2023-12-13
# 26     Credit Card  In-store       2023-04-20
# 27     Credit Card  Takeaway       2023-04-10
# 28     Credit Card       NaN       2023-03-11
# 29  Digital Wallet  Takeaway            ERROR

# %%
#last 5 rows by default or last x rows where x is the parameter of tail fucntion
df.tail(30)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 9970    TXN_5762440  Sandwich        5            4.0        20.0
# 9971    TXN_6120851     Salad        5            5.0        25.0
# 9972    TXN_3124078      Cake        4            3.0        12.0
# 9973    TXN_7936002     Salad        2            5.0        10.0
# 9974    TXN_8076061       Tea        4            1.5         6.0
# 9975    TXN_9668108      Cake        1            3.0         3.0
# 9976    TXN_3528020    Cookie        1            1.0         1.0
# 9977    TXN_5548914     Juice        2            3.0       ERROR
# 9978    TXN_4302199       Tea        3            1.5         4.5
# 9979    TXN_9933628  Smoothie        5            4.0        20.0
# 9980    TXN_6796890       Tea        4            1.5         6.0
# 9981    TXN_4583012     ERROR        5            4.0        20.0
# 9982    TXN_8567525    Cookie        2            1.0         2.0
# 9983    TXN_9226047  Smoothie        3            4.0        12.0
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0         4.0
# 9985    TXN_3297457      Cake        2            3.0         6.0
# 9986    TXN_2858441  Sandwich        2            4.0         8.0
# 9987    TXN_1784478     Juice        5            3.0        15.0
# 9988    TXN_9594133      Cake        5            3.0         NaN
# 9989    TXN_1741685     Juice        5            3.0        15.0
# 9990    TXN_1538510    Coffee        5            2.0        10.0
# 9991    TXN_3897619  Sandwich        3            4.0        12.0
# 9992    TXN_2739140  Smoothie        4            4.0        16.0
# 9993    TXN_4766549  Smoothie        2            4.0         NaN
# 9994    TXN_7851634   UNKNOWN        4            4.0        16.0
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 9970            Cash  In-store       2023-03-05
# 9971            Cash  Takeaway       2023-02-04
# 9972         UNKNOWN  In-store       2023-08-06
# 9973  Digital Wallet       NaN       2023-01-26
# 9974            Cash  In-store       2023-04-01
# 9975            Cash  In-store       2023-01-20
# 9976             NaN  Takeaway       2023-08-26
# 9977  Digital Wallet  In-store       2023-11-04
# 9978             NaN       NaN       2023-02-16
# 9979            Cash  In-store       2023-07-20
# 9980         UNKNOWN       NaN       2023-08-24
# 9981  Digital Wallet       NaN       2023-02-27
# 9982             NaN  Takeaway       2023-12-30
# 9983            Cash       NaN          UNKNOWN
# 9984            Cash  Takeaway       2023-07-27
# 9985             NaN   UNKNOWN       2023-01-03
# 9986     Credit Card  In-store       2023-12-14
# 9987            Cash       NaN       2023-07-31
# 9988           ERROR       NaN              NaN
# 9989            Cash       NaN       2023-08-18
# 9990  Digital Wallet       NaN       2023-05-22
# 9991            Cash  Takeaway       2023-02-24
# 9992         UNKNOWN  In-store       2023-07-05
# 9993            Cash       NaN       2023-10-20
# 9994             NaN       NaN       2023-01-08
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_1961373  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
#select n random rows from the df
df.sample(10)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 8989    TXN_7353685  Sandwich        2            4.0         NaN
# 2284    TXN_8379880     Juice  UNKNOWN            3.0         9.0
# 6044    TXN_1900906    Coffee        5            2.0       ERROR
# 5461    TXN_5697778      Cake        3            3.0         9.0
# 6228    TXN_4602865    Cookie        5            1.0         5.0
# 3190    TXN_6149748     Salad        3            5.0        15.0
# 8508    TXN_8787149     Juice        1            3.0         3.0
# 7255    TXN_6598343     Juice        4            3.0        12.0
# 2218    TXN_4959129       NaN        2            3.0         6.0
# 3400    TXN_6131195     Salad        1            5.0         5.0
#
#       Payment Method  Location Transaction Date
# 8989             NaN  In-store          UNKNOWN
# 2284             NaN  Takeaway       2023-05-24
# 6044            Cash       NaN       2023-01-31
# 5461            Cash       NaN       2023-03-08
# 6228  Digital Wallet  Takeaway       2023-09-27
# 3190     Credit Card       NaN       2023-07-06
# 8508             NaN     ERROR       2023-04-20
# 7255             NaN       NaN       2023-07-10
# 2218     Credit Card  In-store       2023-06-24
# 3400             NaN       NaN       2023-10-24

# %%
#output error most probably because the dtype is object not numerical; the object must be comparable
df.nlargest(10, 'Quantity')
df.nsmallest(10, 'Price')

# %%
#outputs an errir because the column has strings as NAN and can not be compared to a number ; data shall be cleaned first
df[df['Price Per Unit'] > 50]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df[df['Price Per Unit'] > 50]
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6132 return self._construct_result(res_values, name=res_name)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df[df['Item'] == 'Juice']
# Out:
#      Transaction ID   Item Quantity Price Per Unit Total Spent  \
# 17      TXN_6769710  Juice        2            3.0         6.0
# 19      TXN_3709394  Juice        4            3.0        12.0
# 27      TXN_5695074  Juice        4            3.0        12.0
# 43      TXN_9620080  Juice        4            3.0        12.0
# 46      TXN_8078640  Juice        4            3.0        12.0
# ...             ...    ...      ...            ...         ...
# 9960    TXN_3546629  Juice        5            3.0        15.0
# 9967    TXN_8563793  Juice        4            3.0        12.0
# 9977    TXN_5548914  Juice        2            3.0       ERROR
# 9987    TXN_1784478  Juice        5            3.0        15.0
# 9989    TXN_1741685  Juice        5            3.0        15.0
#
#       Payment Method  Location Transaction Date
# 17              Cash  In-store       2023-02-24
# 19              Cash  Takeaway       2023-01-15
# 27       Credit Card  Takeaway       2023-04-10
# 43               NaN  Takeaway       2023-10-02
# 46    Digital Wallet  In-store       2023-11-03
# ...              ...       ...              ...
# 9960             NaN  In-store       2023-03-04
# 9967             NaN  In-store       2023-03-26
# 9977  Digital Wallet  In-store       2023-11-04
# 9987            Cash       NaN       2023-07-31
# 9989            Cash       NaN       2023-08-18
#
# [1171 rows x 8 columns]

# %%
#outputs an error without the brackets 
df[(df['Item'] == 'Juice') & (df['Payment Method'] == 'Cash')]
# Out:
#      Transaction ID   Item Quantity Price Per Unit Total Spent Payment Method  \
# 17      TXN_6769710  Juice        2            3.0         6.0           Cash
# 19      TXN_3709394  Juice        4            3.0        12.0           Cash
# 48      TXN_8201146  Juice        5            3.0        15.0           Cash
# 66      TXN_8501819  Juice      NaN            3.0         6.0           Cash
# 79      TXN_3829165  Juice        4            3.0        12.0           Cash
# ...             ...    ...      ...            ...         ...            ...
# 9899    TXN_6188262  Juice        1            3.0         3.0           Cash
# 9929    TXN_6049240  Juice        1            3.0         3.0           Cash
# 9941    TXN_4224427  Juice        4            3.0        12.0           Cash
# 9987    TXN_1784478  Juice        5            3.0        15.0           Cash
# 9989    TXN_1741685  Juice        5            3.0        15.0           Cash
#
#       Location Transaction Date
# 17    In-store       2023-02-24
# 19    Takeaway       2023-01-15
# 48         NaN       2023-06-26
# 66         NaN       2023-03-30
# 79    In-store       2023-06-15
# ...        ...              ...
# 9899  Takeaway       2023-10-24
# 9929       NaN       2023-05-31
# 9941  Takeaway       2023-01-23
# 9987       NaN       2023-07-31
# 9989       NaN       2023-08-18
#
# [266 rows x 8 columns]

# %%
df[['Location']]
# Out:
#       Location
# 0     Takeaway
# 1     In-store
# 2     In-store
# 3      UNKNOWN
# 4     In-store
# ...        ...
# 9995   UNKNOWN
# 9996       NaN
# 9997       NaN
# 9998       NaN
# 9999  In-store
#
# [10000 rows x 1 columns]

# %%
df[['Item', 'Quantity']]
# Out:
#           Item Quantity
# 0       Coffee        2
# 1         Cake        4
# 2       Cookie        4
# 3        Salad        2
# 4       Coffee        2
# ...        ...      ...
# 9995    Coffee        2
# 9996       NaN        3
# 9997    Coffee        4
# 9998    Cookie        3
# 9999  Sandwich        3
#
# [10000 rows x 2 columns]

# %%
#select all columns between Item and location columns
df.loc[:, 'Item':'Location']
# Out:
#           Item Quantity Price Per Unit Total Spent  Payment Method  Location
# 0       Coffee        2            2.0         4.0     Credit Card  Takeaway
# 1         Cake        4            3.0        12.0            Cash  In-store
# 2       Cookie        4            1.0       ERROR     Credit Card  In-store
# 3        Salad        2            5.0        10.0         UNKNOWN   UNKNOWN
# 4       Coffee        2            2.0         4.0  Digital Wallet  In-store
# ...        ...      ...            ...         ...             ...       ...
# 9995    Coffee        2            2.0         4.0             NaN   UNKNOWN
# 9996       NaN        3            NaN         3.0  Digital Wallet       NaN
# 9997    Coffee        4            2.0         8.0  Digital Wallet       NaN
# 9998    Cookie        3            NaN         3.0  Digital Wallet       NaN
# 9999  Sandwich        3            4.0        12.0            Cash  In-store
#
# [10000 rows x 6 columns]

# %%
df.Item.unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', nan, 'ERROR', 'Juice', 'Tea'], dtype=object)

# %%
df['Price Per Unit'].unique()
# Out:
# array(['2.0', '3.0', '1.0', '5.0', '4.0', '1.5', nan, 'ERROR', 'UNKNOWN'],
#       dtype=object)

# %%
df.Item.value_counts()
# Out:
# Item
# Juice       1171
# Coffee      1165
# Salad       1148
# Cake        1139
# Sandwich    1131
# Smoothie    1096
# Cookie      1092
# Tea         1089
# UNKNOWN      344
# ERROR        292
# Name: count, dtype: int64

# %%
#error becuase of string values in price column
df['Price Per Unit'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df['Price Per Unit'].sum()
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\series.py:6539, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6530 @doc(make_doc("sum", ndim=1))
#    6531 def sum(
#    6532     self,
#    (...)   6537     **kwargs,
#    6538 ):
# -> 6539     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\generic.py:12525, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12517 def sum(
#   12518     self,
#   12519     axis: Axis | None = 0,
#    (...)  12523     **kwargs,
#   12524 ):
# > 12525     return self._min_count_stat_function(
#   12526         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12527     )
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\generic.py:12508, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12505 elif axis is lib.no_default:
#   12506     axis = 0
# > 12508 return self._reduce(
#   12509     func,
#   12510     name=name,
#   12511     axis=axis,
#   12512     skipna=skipna,
#   12513     numeric_only=numeric_only,
#   12514     min_count=min_count,
#   12515 )
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6463     # GH#47500 - change to TypeError to match other methods
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     474         results = [func(x, **kwargs) for x in arrs]
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\nanops.py:646, in nansum(values, axis, skipna, min_count, mask)
#     643 elif dtype.kind == "m":
#     644     dtype_sum = np.dtype(np.float64)
# --> 646 the_sum = values.sum(axis, dtype=dtype_sum)
#     647 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     649 return the_sum
#
# File ~\miniconda\envs\konecta\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
df['Price Per Unit'].min()
df['Price Per Unit'].max()
df['Price Per Unit'].mean()
df['Price Per Unit'].median()
df['Price Per Unit'].var()
df['Price Per Unit'].std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df['Price Per Unit'].min()
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\series.py:6518, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6510 @doc(make_doc("min", ndim=1))
#    6511 def min(
#    6512     self,
#    (...)   6516     **kwargs,
#    6517 ):
# -> 6518     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\generic.py:12407, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12400 def min(
#   12401     self,
#   12402     axis: Axis | None = 0,
#    (...)  12405     **kwargs,
#   12406 ):
# > 12407     return self._stat_function(
#   12408         "min",
#   12409         nanops.nanmin,
#   12410         axis,
#   12411         skipna,
#   12412         numeric_only,
#   12413         **kwargs,
#   12414     )
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12392 nv.validate_func(name, (), kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6463     # GH#47500 - change to TypeError to match other methods
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\miniconda\envs\konecta\Lib\site-packages\pandas\core\nanops.py:1098, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1093     return _na_for_min_count(values, axis)
#    1095 values, mask = _get_values(
#    1096     values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1097 )
# -> 1098 result = getattr(values, meth)(axis)
#    1099 result = _maybe_null_out(result, axis, mask, values.shape)
#    1100 return result
#
# File ~\miniconda\envs\konecta\Lib\site-packages\numpy\core\_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '<=' not supported between instances of 'str' and 'float'

# %%
#return true is data is missing (nan) error,unknown are not null
df.isnull()
# Out:
#       Transaction ID   Item  Quantity  Price Per Unit  Total Spent  \
# 0              False  False     False           False        False
# 1              False  False     False           False        False
# 2              False  False     False           False        False
# 3              False  False     False           False        False
# 4              False  False     False           False        False
# ...              ...    ...       ...             ...          ...
# 9995           False  False     False           False        False
# 9996           False   True     False            True        False
# 9997           False  False     False           False        False
# 9998           False  False     False            True        False
# 9999           False  False     False           False        False
#
#       Payment Method  Location  Transaction Date
# 0              False     False             False
# 1              False     False             False
# 2              False     False             False
# 3              False     False             False
# 4              False     False             False
# ...              ...       ...               ...
# 9995            True     False             False
# 9996           False      True             False
# 9997           False      True             False
# 9998           False      True             False
# 9999           False     False             False
#
# [10000 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df.columns[df.isin(['UNKNOWN', 'ERROR']).any()]
# Out:
# Index(['Item', 'Quantity', 'Price Per Unit', 'Total Spent', 'Payment Method',
#        'Location', 'Transaction Date'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %%
#must assign inplace = true to see the effect
df.replace(to_replace=['UNKNOWN', 'ERROR'], value=np.nan, inplace=True)

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'], errors='coerce')
df['Total Spent'] = pd.to_numeric(df['Total Spent'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             479
# Price Per Unit       533
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %% [markdown]
# ## Logical Relationships

# %%
# Total spent= Quantity * Price per unit
# Price per unit = Total spent/ Quantity
# Some items have their prices written once but other times NAN so they can be filled using the value in the other transaction

# %%
df.loc[(
    df['Quantity'].notna() &
    df['Price Per Unit'].notna() &
    pd.isna(df['Total Spent'])
), 'Total Spent' ] = df['Quantity'] * df['Price Per Unit']

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 969
# Quantity              38
# Price Per Unit        54
# Total Spent           23
# Payment Method      3178
# Location            3961
# Transaction Date     460
# dtype: int64

# %%
df.loc[(
    df['Total Spent'].notna() &
    df['Price Per Unit'].notna() &
    pd.isna(df['Quantity'])
), 'Quantity' ] = df['Total Spent'] / df['Price Per Unit']

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 969
# Quantity              23
# Price Per Unit        54
# Total Spent           23
# Payment Method      3178
# Location            3961
# Transaction Date     460
# dtype: int64

# %%
df[['Item','Price Per Unit']]
# Out:
#           Item  Price Per Unit
# 0       Coffee             2.0
# 1         Cake             3.0
# 2       Cookie             1.0
# 3        Salad             5.0
# 4       Coffee             2.0
# ...        ...             ...
# 9995    Coffee             2.0
# 9996       NaN             NaN
# 9997    Coffee             2.0
# 9998    Cookie             1.0
# 9999  Sandwich             4.0
#
# [10000 rows x 2 columns]

# %%
df.loc[(
    df['Item'] == 'Coffee'), 'Price Per Unit' ] = 2.0

# %%
df.loc[(
    df['Item'] == 'Cake'), 'Price Per Unit' ] = 3.0

# %%
df.loc[(
    df['Item'] == 'Cookie'), 'Price Per Unit' ] = 1.0

# %%
df.loc[(
    df['Item'] == 'Sandwich'), 'Price Per Unit' ] = 4.0

# %%
df.loc[(
    df['Item'] == 'Salad'), 'Price Per Unit' ] = 5.0

# %%
df.loc[(
    df['Item'] == 'Tea'), 'Price Per Unit' ] = 1.5

# %%
df.loc[(
    df['Item'] == 'Juice'), 'Price Per Unit' ] = 3.0

# %%
df.loc[(
    df['Item'] == 'Smoothie'), 'Price Per Unit' ] = 4.0

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 969
# Quantity              23
# Price Per Unit        54
# Total Spent           23
# Payment Method      3178
# Location            3961
# Transaction Date     460
# dtype: int64

# %%
df.loc[(
    df['Total Spent'].notna() &
    df['Quantity'].notna() &
    pd.isna(df['Price Per Unit'])
), 'Price Per Unit' ] = df['Total Spent'] / df['Quantity']

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 969
# Quantity              23
# Price Per Unit         6
# Total Spent           23
# Payment Method      3178
# Location            3961
# Transaction Date     460
# dtype: int64

# %%
df.loc[(
    df['Price Per Unit'] == 2.0), 'Item' ] = 'Coffee'

# %%
df.loc[(
    df['Price Per Unit'] == 1.0), 'Item' ] = 'Cookie'

# %%
df.loc[(
    df['Price Per Unit'] == 1.5), 'Item' ] = 'Tea'

# %%
df.loc[(
    df['Price Per Unit'] == 5.0), 'Item' ] = 'Salad'

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 480
# Quantity              23
# Price Per Unit         6
# Total Spent           23
# Payment Method      3178
# Location            3961
# Transaction Date     460
# dtype: int64

# %%
#print(df.to_string()) 
# NaN in Price per unit bec NaN in item
#can drop rows where item and total price are Nan
#there are rows having total price with item, quantity and price per unit Nan
#there are rows with quantity and total price Nan
#Quantity and Nan are missing together

# %% [markdown]
# ## Normalize Date Column

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], format='mixed')

# %%
#the first line is wrong because it assigns a sorted dataframe to a single column
#df['Transaction Date'] = df.sort_values('Transaction Date', ascending=True)
df = df.sort_values('Transaction Date', ascending=True)

# %%
df['Transaction Date'] = df['Transaction Date'].ffill()

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 480
# Quantity              23
# Price Per Unit         6
# Total Spent           23
# Payment Method      3178
# Location            3961
# Transaction Date       0
# dtype: int64

# %%
#print(df.to_string())

# %% [markdown]
# ## Standerdize Categorical Columns

# %%
df['Item'] = df['Item'].str.capitalize()
df['Payment Method'] = df['Payment Method'].str.capitalize()
df['Location'] = df['Location'].str.capitalize()

# %%
df['Item'] = df['Item'].str.strip()
df['Location'] = df['Location'].str.strip()
df['Payment Method'] = df['Payment Method'].str.strip()

# %%
df['Item'] = df['Item'].str.replace(r'[^\w\s]', '', regex=True)
df['Payment Method'] = df['Payment Method'].str.replace(r'[^\w\s]', '', regex=True)
df['Location'] = df['Location'].str.replace(r'[^\w\s]', '', regex=True)

# %%
df[['Item', 'Location', 'Payment Method']] = df[['Item', 'Location', 'Payment Method']].fillna('Unspecified')
df['Payment Method'] = df['Payment Method'].str.replace('Digital wallet', 'E-wallet')

# %%
df['Location'].unique()
# Out:
# array(['Takeaway', 'Instore', 'Unspecified'], dtype=object)

# %%
df['Payment Method'].unique()
# Out:
# array(['E-wallet', 'Unspecified', 'Cash', 'Credit card'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Transaction ID       0
# Item                 0
# Quantity            23
# Price Per Unit       6
# Total Spent         23
# Payment Method       0
# Location             0
# Transaction Date     0
# dtype: int64

# %%
#print(df.to_string())

# %% [markdown]
# ## Removing Duplicates

# %%
df_cleaned = df.drop_duplicates()
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 8015    TXN_4801947     Juice       1.0             3.0          3.0
# 9063    TXN_9161256  Smoothie       2.0             4.0          8.0
# 7309    TXN_6093955       Tea       5.0             1.5          7.5
# 1425    TXN_8842223  Sandwich       5.0             4.0         20.0
# 1777    TXN_7367474     Juice       5.0             3.0         15.0
# ...             ...       ...       ...             ...          ...
# 9933    TXN_9460419      Cake       1.0             3.0          3.0
# 9937    TXN_8253472      Cake       1.0             3.0          3.0
# 9949    TXN_3130865     Juice       3.0             3.0          9.0
# 9983    TXN_9226047  Smoothie       3.0             4.0         12.0
# 9988    TXN_9594133      Cake       5.0             3.0         15.0
#
#      Payment Method     Location Transaction Date
# 8015       E-wallet     Takeaway       2023-01-01
# 9063       E-wallet      Instore       2023-01-01
# 7309    Unspecified     Takeaway       2023-01-01
# 1425       E-wallet      Instore       2023-01-01
# 1777       E-wallet     Takeaway       2023-01-01
# ...             ...          ...              ...
# 9933    Unspecified     Takeaway       2023-12-31
# 9937    Unspecified  Unspecified       2023-12-31
# 9949    Unspecified      Instore       2023-12-31
# 9983           Cash  Unspecified       2023-12-31
# 9988    Unspecified  Unspecified       2023-12-31
#
# [10000 rows x 8 columns]

# %%
df['Transaction ID'].nunique()
# Out:
# 9977

# %%
df[df['Quantity'] <= 0.0]
#no negative or 0 in quantity column
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df[df['Price Per Unit'] <= 0.0]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df[df['Total Spent'] <= 0.0]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df[df['Quantity'].isnull()]
# Out:
#      Transaction ID         Item  Quantity  Price Per Unit  Total Spent  \
# 7297    TXN_9944500     Smoothie       NaN             4.0          NaN
# 9869    TXN_1975184       Coffee       NaN             2.0          NaN
# 9590    TXN_9924732     Sandwich       NaN             4.0          NaN
# 641     TXN_2962976        Juice       NaN             3.0          NaN
# 3224    TXN_6297232       Coffee       NaN             2.0          NaN
# 8574    TXN_2546684        Juice       NaN             3.0          NaN
# 278     TXN_3229409        Juice       NaN             3.0          NaN
# 8021    TXN_2428781        Salad       NaN             5.0          NaN
# 738     TXN_8696094     Sandwich       NaN             4.0          NaN
# 236     TXN_8562645        Salad       NaN             5.0          NaN
# 8443    TXN_2023651     Sandwich       NaN             4.0          NaN
# 3779    TXN_7376255  Unspecified       NaN             NaN         25.0
# 8465    TXN_9669616       Coffee       NaN             2.0          NaN
# 5841    TXN_5884081       Cookie       NaN             1.0          NaN
# 3401    TXN_3251829          Tea       NaN             1.5          NaN
# 8732    TXN_4550558       Cookie       NaN             1.0          NaN
# 9819    TXN_1208561  Unspecified       NaN             NaN         20.0
# 8479    TXN_1547245     Sandwich       NaN             4.0          NaN
# 4257    TXN_6470865       Coffee       NaN             2.0          NaN
# 3203    TXN_4565754     Smoothie       NaN             4.0          NaN
# 2796    TXN_9188692         Cake       NaN             3.0          NaN
# 7597    TXN_1082717  Unspecified       NaN             NaN          9.0
# 7029    TXN_4628338       Coffee       NaN             2.0          NaN
#
#      Payment Method     Location Transaction Date
# 7297           Cash      Instore       2023-01-03
# 9869       E-wallet  Unspecified       2023-01-15
# 9590    Credit card      Instore       2023-01-18
# 641     Unspecified  Unspecified       2023-03-17
# 3224    Unspecified  Unspecified       2023-04-07
# 8574       E-wallet     Takeaway       2023-04-08
# 278            Cash     Takeaway       2023-04-15
# 8021    Unspecified      Instore       2023-05-09
# 738     Unspecified     Takeaway       2023-05-14
# 236     Unspecified      Instore       2023-05-18
# 8443           Cash      Instore       2023-05-25
# 3779    Unspecified      Instore       2023-05-27
# 8465    Unspecified  Unspecified       2023-06-03
# 5841       E-wallet      Instore       2023-07-05
# 3401       E-wallet      Instore       2023-07-25
# 8732    Credit card      Instore       2023-08-04
# 9819    Credit card  Unspecified       2023-08-19
# 8479    Unspecified     Takeaway       2023-09-11
# 4257       E-wallet     Takeaway       2023-09-18
# 3203       E-wallet     Takeaway       2023-10-06
# 2796    Credit card  Unspecified       2023-12-01
# 7597       E-wallet      Instore       2023-12-13
# 7029           Cash  Unspecified       2023-12-25

# %%
df[df['Total Spent'].isnull()]
# Out:
#      Transaction ID         Item  Quantity  Price Per Unit  Total Spent  \
# 7297    TXN_9944500     Smoothie       NaN             4.0          NaN
# 9869    TXN_1975184       Coffee       NaN             2.0          NaN
# 9590    TXN_9924732     Sandwich       NaN             4.0          NaN
# 1761    TXN_3611851  Unspecified       4.0             NaN          NaN
# 641     TXN_2962976        Juice       NaN             3.0          NaN
# 3224    TXN_6297232       Coffee       NaN             2.0          NaN
# 8574    TXN_2546684        Juice       NaN             3.0          NaN
# 278     TXN_3229409        Juice       NaN             3.0          NaN
# 8021    TXN_2428781        Salad       NaN             5.0          NaN
# 738     TXN_8696094     Sandwich       NaN             4.0          NaN
# 236     TXN_8562645        Salad       NaN             5.0          NaN
# 8443    TXN_2023651     Sandwich       NaN             4.0          NaN
# 8465    TXN_9669616       Coffee       NaN             2.0          NaN
# 5841    TXN_5884081       Cookie       NaN             1.0          NaN
# 3401    TXN_3251829          Tea       NaN             1.5          NaN
# 8732    TXN_4550558       Cookie       NaN             1.0          NaN
# 8479    TXN_1547245     Sandwich       NaN             4.0          NaN
# 4257    TXN_6470865       Coffee       NaN             2.0          NaN
# 3203    TXN_4565754     Smoothie       NaN             4.0          NaN
# 2796    TXN_9188692         Cake       NaN             3.0          NaN
# 2289    TXN_7524977  Unspecified       4.0             NaN          NaN
# 4152    TXN_9646000  Unspecified       2.0             NaN          NaN
# 7029    TXN_4628338       Coffee       NaN             2.0          NaN
#
#      Payment Method     Location Transaction Date
# 7297           Cash      Instore       2023-01-03
# 9869       E-wallet  Unspecified       2023-01-15
# 9590    Credit card      Instore       2023-01-18
# 1761    Credit card  Unspecified       2023-02-09
# 641     Unspecified  Unspecified       2023-03-17
# 3224    Unspecified  Unspecified       2023-04-07
# 8574       E-wallet     Takeaway       2023-04-08
# 278            Cash     Takeaway       2023-04-15
# 8021    Unspecified      Instore       2023-05-09
# 738     Unspecified     Takeaway       2023-05-14
# 236     Unspecified      Instore       2023-05-18
# 8443           Cash      Instore       2023-05-25
# 8465    Unspecified  Unspecified       2023-06-03
# 5841       E-wallet      Instore       2023-07-05
# 3401       E-wallet      Instore       2023-07-25
# 8732    Credit card      Instore       2023-08-04
# 8479    Unspecified     Takeaway       2023-09-11
# 4257       E-wallet     Takeaway       2023-09-18
# 3203       E-wallet     Takeaway       2023-10-06
# 2796    Credit card  Unspecified       2023-12-01
# 2289    Unspecified  Unspecified       2023-12-09
# 4152    Unspecified      Instore       2023-12-14
# 7029           Cash  Unspecified       2023-12-25

# %%
#drop rows where Total Spent isnull
df = df.dropna(subset=['Total Spent'])

# %%
avg_quantity = df['Quantity'].mean()
avg_quantity
df.loc[:, 'Quantity'] = df['Quantity'].fillna(avg_quantity)
df.loc[:, 'Price Per Unit'] = df['Price Per Unit'].fillna(df['Total Spent']/ df['Quantity'])

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %% [markdown]
# ## Derived Columns

# %%
df.loc[:,'Month'] = df['Transaction Date'].dt.month_name()
df.loc[:,'Weekday'] = df['Transaction Date'].dt.day_name()
df.loc[:,'Hour'] = df['Transaction Date'].dt.hour

# %%
#print(df.to_string())

# %%
avg_price_per_item = df.groupby(by='Item')['Price Per Unit'].mean()
avg_price_per_item
df.loc[:,'Avg Price Per Item'] = df['Item'].map(avg_price_per_item)

# %%
avg_qu_per_item = df.groupby(by='Item')['Quantity'].mean()
avg_qu_per_item
df.loc[:,'Avg Quantity Per Item'] = df['Item'].map(avg_qu_per_item)

# %%
avg_price_per_location = df.groupby('Location')['Price Per Unit'].mean()
df.loc[:,'Avg Price Per Location'] = df['Location'].map(avg_price_per_location)

# %% [markdown]
# ## Plotting

# %%
conda install matplotlib
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
item_revenue = df.groupby('Item')['Total Spent'].sum()
item_revenue.plot.pie(autopct='%1.1f%%', y='')
# Out:
# <Axes: ylabel='Total Spent'>

# %%
item_quantity = df.groupby('Item')['Quantity'].sum()
item_quantity.plot.pie(autopct='%1.1f%%', y='')
# Out:
# <Axes: ylabel='Quantity'>

# %%
total_revenue = df['Total Spent'].sum()
total_revenue
# Out:
# 89096.0

# %%
item_quantity = df.groupby('Item')['Quantity'].sum()
item_quantity
# Out:
# Item
# Cake           3468
# Coffee         3904
# Cookie         3598
# Juice          3505
# Salad          3819
# Sandwich       3429
# Smoothie       3336
# Tea            3650
# Unspecified    1470
# Name: Quantity, dtype: int32

# %%
item_revenue
# Out:
# Item
# Cake           10404.0
# Coffee          7808.0
# Cookie          3598.0
# Juice          10515.0
# Salad          19095.0
# Sandwich       13716.0
# Smoothie       13344.0
# Tea             5475.0
# Unspecified     5141.0
# Name: Total Spent, dtype: float64
